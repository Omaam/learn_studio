# %%
from skimage import io
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = io.imread("../dataset/images/imori_256x256.png")

plt.imshow(img)
plt.show()

# %%
print(img.shape)
print(img.dtype)
# Out:
# (256, 256, 3)
# uint8

# %%
img2 = img.copy()
h, w, c = img2.shape

img2[:h//2, :w//2] = img2[:h//2, :w//2, ::-1]

fig, ax = plt.subplots(1, 2)
ax[0].imshow(img)
ax[1].imshow(img2)
plt.show()
